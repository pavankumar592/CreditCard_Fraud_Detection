# %% [markdown]
# ### Loading libararies

# %%
# loading R packages

library(tidyverse)
library(forcats)
library(ggplot2)
library(tidyr)
library(tidymodels)
library(pROC)
library(GGally)
# Out:
# ── Attaching packages ───────────────────────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.3     ✔ purrr   0.3.4
# ✔ tibble  3.0.4     ✔ dplyr   1.0.2
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.0
#
# ── Conflicts ──────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# ── Attaching packages ──────────────────────────────────────────────────────────────────────────────────────────────── tidymodels 0.1.2 ──
#
# ✔ broom     0.7.2      ✔ recipes   0.1.15
# ✔ dials     0.0.9      ✔ rsample   0.0.8
# ✔ infer     0.5.3      ✔ tune      0.1.2
# ✔ modeldata 0.1.0      ✔ workflows 0.2.1
# ✔ parsnip   0.1.4      ✔ yardstick 0.0.7
#
# ── Conflicts ─────────────────────────────────────────────────────────────────────────────────────────────────── tidymodels_conflicts() ──
# ✖ scales::discard() masks purrr::discard()
# ✖ dplyr::filter()   masks stats::filter()
# ✖ recipes::fixed()  masks stringr::fixed()
# ✖ dplyr::lag()      masks stats::lag()
# ✖ yardstick::spec() masks readr::spec()
# ✖ recipes::step()   masks stats::step()
#
# Type 'citation("pROC")' for a citation.
#
#
# Attaching package: ‘pROC’
#
#
# The following objects are masked from ‘package:stats’:
#
#     cov, smooth, var
#
#
# Registered S3 method overwritten by 'GGally':
#   method from
#   +.gg   ggplot2

# %% [markdown]
# ### Import Dataset
#
# The dataset used is available here: https://www.kaggle.com/mlg-ulb/creditcardfraud
#
# Let's have a look at the data

# %%
credit_card <- read_csv("Data/creditcard.csv")
head(credit_card)
# Out:
# ── Column specification ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# cols(
#   .default = col_double()
# )
# ℹ Use `spec()` for the full column specifications.
#   Time V1         V2          V3        V4         V5          V6
# 1 0    -1.3598071 -0.07278117 2.5363467  1.3781552 -0.33832077  0.46238778
# 2 0     1.1918571  0.26615071 0.1664801  0.4481541  0.06001765 -0.08236081
# 3 1    -1.3583541 -1.34016307 1.7732093  0.3797796 -0.50319813  1.80049938
# 4 1    -0.9662717 -0.18522601 1.7929933 -0.8632913 -0.01030888  1.24720317
# 5 2    -1.1582331  0.87773675 1.5487178  0.4030339 -0.40719338  0.09592146
# 6 2    -0.4259659  0.96052304 1.1411093 -0.1682521  0.42098688 -0.02972755
#   V7          V8          V9         ⋯ V21          V22          V23
# 1  0.23959855  0.09869790  0.3637870 ⋯ -0.018306778  0.277837576 -0.11047391
# 2 -0.07880298  0.08510165 -0.2554251 ⋯ -0.225775248 -0.638671953  0.10128802
# 3  0.79146096  0.24767579 -1.5146543 ⋯  0.247998153  0.771679402  0.90941226
# 4  0.23760894  0.37743587 -1.3870241 ⋯ -0.108300452  0.005273597 -0.19032052
# 5  0.59294075 -0.27053268  0.8177393 ⋯ -0.009430697  0.798278495 -0.13745808
# 6  0.47620095  0.26031433 -0.5686714 ⋯ -0.208253515 -0.559824796 -0.02639767
#   V24         V25        V26        V27          V28         Amount Class
# 1  0.06692807  0.1285394 -0.1891148  0.133558377 -0.02105305 149.62 0
# 2 -0.33984648  0.1671704  0.1258945 -0.008983099  0.01472417   2.69 0
# 3 -0.68928096 -0.3276418 -0.1390966 -0.055352794 -0.05975184 378.66 0
# 4 -1.17557533  0.6473760 -0.2219288  0.062722849  0.06145763 123.50 0
# 5  0.14126698 -0.2060096  0.5022922  0.219422230  0.21515315  69.99 0
# 6 -0.37142658 -0.2327938  0.1059148  0.253844225  0.08108026   3.67 0

# %%
colnames(credit_card)
# Out:
#  [1] "Time"   "V1"     "V2"     "V3"     "V4"     "V5"     "V6"     "V7"
#  [9] "V8"     "V9"     "V10"    "V11"    "V12"    "V13"    "V14"    "V15"
# [17] "V16"    "V17"    "V18"    "V19"    "V20"    "V21"    "V22"    "V23"
# [25] "V24"    "V25"    "V26"    "V27"    "V28"    "Amount" "Class"

# %% [markdown]
# ### Explanatory Data Analysis
#
# The data is already scaled by PCA transformation, we don't need any scaling and cleaning.

# %%
credit_split <- initial_split(credit_card, prop = 0.75, strata = Class)
credit_train <- training(credit_split)
credit_test <- testing(credit_split)

# %%
ggplot(gather(credit_train), aes(value)) + 
    geom_histogram(bins = 10) + 
    facet_wrap(~key, scales = 'free_x')
# Out:
# plot without title

# %% [markdown]
# Look at the histogram above, the most of V's are centered around 0 with some or no outliers. It can be seen as there were very few fraudulent cases over valid cases in the class histogram.

# %%
# determine the number of fraud cases
fraud <- filter(credit_train, Class == 1)
valid <- filter(credit_train, Class == 0)
nrow(fraud)
nrow(valid)
# Out:
# [1] 363
# [1] 213243

# %% [markdown]
# ### Fitting Logistic Regression
#
# Logistic Regression Model is used to predict the credit card fraud/not fraud.

# %%
Logistic_model = glm(Class~.,credit_train, family = binomial())
summary(Logistic_model)
# Out:
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Call:
# glm(formula = Class ~ ., family = binomial(), data = credit_train)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -4.9344  -0.0285  -0.0184  -0.0113   4.6341
#
# Coefficients:
#               Estimate Std. Error z value Pr(>|z|)
# (Intercept) -8.673e+00  3.032e-01 -28.604  < 2e-16 ***
# Time        -2.035e-06  2.604e-06  -0.782  0.43441
# V1           8.970e-02  4.907e-02   1.828  0.06755 .
# V2           3.782e-02  7.267e-02   0.520  0.60280
# V3           3.238e-02  6.126e-02   0.529  0.59714
# V4           7.939e-01  1.003e-01   7.912 2.52e-15 ***
# V5           1.232e-01  8.211e-02   1.500  0.13364
# V6          -1.287e-01  8.816e-02  -1.459  0.14445
# V7          -8.506e-02  8.182e-02  -1.040  0.29852
# V8          -1.704e-01  3.428e-02  -4.969 6.72e-07 ***
# V9          -1.967e-01  1.417e-01  -1.389  0.16486
# V10         -9.017e-01  1.190e-01  -7.576 3.55e-14 ***
# V11         -3.278e-03  9.371e-02  -0.035  0.97210
# V12          1.217e-01  1.076e-01   1.132  0.25783
# V13         -2.840e-01  9.190e-02  -3.090  0.00200 **
# V14         -5.075e-01  7.263e-02  -6.987 2.81e-12 ***
# V15         -1.726e-01  1.009e-01  -1.711  0.08708 .
# V16         -2.487e-01  1.541e-01  -1.614  0.10663
# V17         -4.702e-02  8.830e-02  -0.533  0.59436
# V18          9.377e-02  1.612e-01   0.582  0.56080
# V19         -2.951e-02  1.177e-01  -0.251  0.80210
# V20         -5.053e-01  9.197e-02  -5.494 3.92e-08 ***
# V21          3.361e-01  6.963e-02   4.827 1.39e-06 ***
# V22          4.820e-01  1.596e-01   3.020  0.00253 **
# V23         -8.012e-02  6.993e-02  -1.146  0.25189
# V24          1.450e-01  1.736e-01   0.836  0.40338
# V25          9.179e-03  1.535e-01   0.060  0.95231
# V26          2.151e-02  2.333e-01   0.092  0.92655
# V27         -8.615e-01  1.353e-01  -6.368 1.92e-10 ***
# V28         -3.096e-01  1.077e-01  -2.874  0.00406 **
# Amount       8.892e-04  4.060e-04   2.190  0.02850 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 5355.4  on 213605  degrees of freedom
# Residual deviance: 1648.2  on 213575  degrees of freedom
# AIC: 1710.2
#
# Number of Fisher Scoring iterations: 12

# %%
plot(Logistic_model)
# Out:
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”

# %% [markdown]
# ### Performance of Logistic Regression
#
# To asses the preformance of Logistic Regression, ROC curve is made. ROC is known as receiver operating characteristics.

# %%
logistic_predict <- predict(Logistic_model,credit_test, probability = TRUE)
auc.gbm = roc(credit_test$Class, logistic_predict, plot = TRUE, col = "blue")
# Out:
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
# plot without title

# %% [markdown]
# An ideal ROC curve will hug the top left corner, so the larger the AUC the better the classifier. The above ROC curve represents that the performance of logistic regression is great. Since the area under the blue curve is really large which is considered very good.
